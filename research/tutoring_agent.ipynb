# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) 

if project_root not in sys.path:
    sys.path.append(project_root)

from backend.src.agents.assistant_agent import AssistantAgent

topic = "Calculus"
subject = "Mathematics"
standard = 11

# 1. Instantiate the agent directly
agent = AssistantAgent()

# 2. Use 'await' directly (works only in Jupyter/IPython)
assistant_response = await agent.run(
    topic=topic,
    subject=subject,
    standard=standard
)

# %%
print(assistant_response)
# Out:
# ### Lesson Planning Prompt for Calculus Curriculum
#
# #### CONTEXT
# Create a 35-50 lesson curriculum for Calculus, tailored to Standard 11 students. The curriculum should be based on the provided topic guide, which includes an introduction to Calculus, resources, and study tips.
#
# #### OBJECTIVES
# The objectives of this curriculum are to:
#
# 1. Introduce students to the fundamental concepts of Calculus, including limits, derivatives, and integrals.
# 2. Develop students' problem-solving skills and ability to apply Calculus to real-world problems.
# 3. Foster a deep understanding of Calculus and its applications in various fields.
#
# #### CONSTRAINTS
# The curriculum should be designed to accommodate the following constraints:
#
# 1. Difficulty level: The curriculum should be challenging but manageable for Standard 11 students.
# 2. Lesson sequence: Break the topic into sequential lessons, ensuring a logical flow of concepts.
# 3. Pace: Ensure the pace suits a Standard 11 student, allowing for adequate time to grasp each concept before moving on to the next.
#
# #### RESOURCES
# The following resources should be utilized to create the curriculum:
#
# 1. Topic guide: The provided HTML document, which includes an introduction to Calculus, resources, and study tips.
# 2. Raw search links: The list of YouTube links provided, which include video explanations and study resources.
#
# #### OUTPUT FORMAT
# Return a 35-50 lesson curriculum, structured as follows:
#
# * Lesson 1: Introduction to Calculus
# * Lesson 2: Limits
# * Lesson 3: Derivatives
# * Lesson 4: Integrals
# * Lesson 5: Applications of Calculus
# * ...
# * Lesson 35-50: Review and Assessment
#
# The curriculum should include a detailed lesson plan, including objectives, materials, procedures, and assessment methods for each lesson.

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) 

if project_root not in sys.path:
    sys.path.append(project_root)

from backend.src.prompts.tutoring_prompt import LESSON_PLANNING_PROMPT
from backend.src.logger import logging
from backend.src.utils import get_llm_lite_1
from langchain_core.messages import SystemMessage
from backend.src.exception import CustomException
import sys

llm_lite = get_llm_lite_1()

async def plan_curriculum(instructions) -> dict:
        try:
            logging.info("Generating curriculum plan...")
            
            prompt = LESSON_PLANNING_PROMPT.format(
                topic = "Calculus",
                subject = "Mathematics",
                standard = 11,
                instructions = instructions
            )

            response = await llm_lite.ainvoke([SystemMessage(content=prompt)])
            
            return {"plannings": response.content}

        except Exception as e:
            raise CustomException(e, sys)

# %%
plans = await plan_curriculum(instructions = assistant_response)

# %%
print(plans["plannings"])
# Out:
# Lesson 1: Introduction to Calculus
# Lesson 2: History and Development of Calculus
# Lesson 3: Basic Concepts and Terminology
# Lesson 4: Limits and Continuity
# Lesson 5: Evaluating Limits
# Lesson 6: Properties of Limits
# Lesson 7: Squeeze Theorem and Infinite Limits
# Lesson 8: Introduction to Derivatives
# Lesson 9: Definition of a Derivative
# Lesson 10: Rules of Differentiation
# Lesson 11: Power Rule and Product Rule
# Lesson 12: Quotient Rule and Chain Rule
# Lesson 13: Implicit Differentiation
# Lesson 14: Higher-Order Derivatives
# Lesson 15: Applications of Derivatives
# Lesson 16: Introduction to Integrals
# Lesson 17: Definition of a Definite Integral
# Lesson 18: Basic Integration Rules
# Lesson 19: Substitution Method
# Lesson 20: Integration by Parts
# Lesson 21: Integration by Partial Fractions
# Lesson 22: Improper Integrals
# Lesson 23: Applications of Integrals
# Lesson 24: Area Between Curves
# Lesson 25: Volume of Solids
# Lesson 26: Surface Area of Solids
# Lesson 27: Introduction to Multivariable Calculus
# Lesson 28: Partial Derivatives
# Lesson 29: Double and Triple Integrals
# Lesson 30: Jacobians and Change of Variables
# Lesson 31: Introduction to Differential Equations
# Lesson 32: Separable Differential Equations
# Lesson 33: First-Order Linear Differential Equations
# Lesson 34: Applications of Differential Equations
# Lesson 35: Review of Limits and Derivatives
# Lesson 36: Review of Integrals and Multivariable Calculus
# Lesson 37: Practice Problems and Case Studies
# Lesson 38: Calculus in Physics and Engineering
# Lesson 39: Calculus in Economics and Computer Science
# Lesson 40: Calculus in Biology and Medicine
# Lesson 41: Review of Applications of Calculus
# Lesson 42: Assessment and Evaluation Strategies
# Lesson 43: Calculus Project Development
# Lesson 44: Presentations and Peer Review
# Lesson 45: Review and Practice for Final Assessment
# Lesson 46: Final Assessment Preparation
# Lesson 47: Review of Weaknesses and Strengths
# Lesson 48: Calculus in Real-World Scenarios
# Lesson 49: Advanced Topics in Calculus
# Lesson 50: Conclusion and Future Directions in Calculus

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) 

if project_root not in sys.path:
    sys.path.append(project_root)

from backend.src.prompts.tutoring_prompt import LESSON_CONTENT_PROMPT
from backend.src.utils import get_llm_1
from langchain_core.messages import SystemMessage
from backend.src.logger import logging
from backend.src.exception import CustomException
import asyncio

llm = get_llm_1()

async def generate_parallel_lessons(plans, topic, subject, standard) -> dict:
        try:
            logging.info("Generating lessons with rate limiting...")

            plannings = plans
            topic = topic
            subject = subject
            standard = standard
            
            lesson_list = [line.strip() for line in plannings.split("\n") if line.strip()]

            # --- KEY FIX: SEMAPHORE ---
            # This limits the agent to only 3 concurrent requests at a time.
            # You can increase to 5 if you have a paid/higher tier API plan.
            sem = asyncio.Semaphore(3) 

            async def generate_single_lesson_safe(lesson_title):
                """Generates content for one lesson, respecting the semaphore limit."""
                async with sem:  # Wait for a 'slot' to open before requesting
                    try:
                        # Add a small delay to be extra safe against RPM limits
                        await asyncio.sleep(0.1) 
                        
                        p = LESSON_CONTENT_PROMPT.format(
                            lesson_title=lesson_title,
                            topic=topic,
                            subject=subject,
                            standard=standard
                        )
                        res = await llm.ainvoke([SystemMessage(content=p)])
                        logging.info(f"Generated: {lesson_title[:30]}...")
                        return lesson_title, res.content
                    
                    except Exception as e:
                        # Log the specific error (likely 429)
                        logging.error(f"Failed to generate {lesson_title}: {str(e)}")
                        # Retry logic could be added here, but for now we return error html
                        return lesson_title, f"<p>Error generating content: {str(e)}</p>"

            # Create tasks
            tasks = [generate_single_lesson_safe(lesson) for lesson in lesson_list]

            # Run tasks (They will now respect the limit of 3 at a time)
            results = await asyncio.gather(*tasks)

            lessons_dict = {title: content for title, content in results}

            logging.info(f"Generated {len(lessons_dict)} lessons successfully.")

            return {"lessons": lessons_dict}

        except Exception as e:
            raise CustomException(e, sys)

# %%
lessons = await generate_parallel_lessons(
    plans = plans["plannings"],
    topic = "Calculus",
    subject = "Mathematics",
    standard = 11
)

# %%
for title, content in lessons["lessons"].items():

    print(title, "\n")
    print(content)
    print("\n")
    print("-" * 100)
# Out:
# Lesson 1: Introduction to Calculus
#
# ### Lesson 1: Introduction to Calculus
#
# ### <h4>What is Calculus?</h4>
#
# Calculus is a branch of mathematics that deals with the study of continuous change, particularly in the context of functions and limits. It is a fundamental subject that has numerous applications in various fields, including physics, engineering, economics, and computer science. Calculus is divided into two main branches: Differential Calculus and Integral Calculus.
#
# ### <h4>History of Calculus</h4>
#
# The development of calculus is attributed to several mathematicians, including Sir Isaac Newton and German mathematician Gottfried Wilhelm Leibniz. Newton developed the method of "fluxions," which is equivalent to the modern method of derivatives. Leibniz, on the other hand, developed the notation and formalism that is used today in calculus. The development of calculus was a gradual process that spanned several centuries, with contributions from many mathematicians.
#
# ### <h4>Key Concepts in Calculus</h4>
#
# Before we dive into the details of calculus, let's introduce some key concepts that are essential to understanding the subject.
#
# - **Functions**: A function is a relation between a set of inputs (called the domain) and a set of possible outputs (called the range). Functions can be represented graphically, algebraically, or numerically.
# - **Limits**: A limit is a value that a function approaches as the input (or independent variable) gets arbitrarily close to a certain point. Limits are used to define the behavior of functions as the input gets arbitrarily close to a certain point.
# - **Derivatives**: A derivative is a measure of how a function changes as its input changes. Derivatives are used to study the rate of change of functions and are a fundamental concept in calculus.
# - **Integrals**: An integral is a measure of the accumulation of a function over a given interval. Integrals are used to study the area under curves, volumes of solids, and other quantities.
#
# ### <h4>Differential Calculus</h4>
#
# Differential calculus is the branch of calculus that deals with the study of rates of change and slopes of curves. It is concerned with the study of derivatives, which are used to measure the rate of change of functions.
#
# - **Derivatives**: A derivative is a measure of how a function changes as its input changes. It is denoted by the symbol `dy/dx` and is read as "the derivative of y with respect to x."
# - **Rules of Differentiation**: There are several rules of differentiation that are used to find the derivatives of functions. These include the power rule, product rule, quotient rule, and chain rule.
#
# ### <h4>Examples of Derivatives</h4>
#
# Let's consider some examples of derivatives to illustrate the concept.
#
# - **Example 1**: Find the derivative of the function `f(x) = 3x^2`.
# - **Solution**: Using the power rule, we get `f'(x) = d(3x^2)/dx = 6x`.
# - **Example 2**: Find the derivative of the function `f(x) = sin(x)`.
# - **Solution**: Using the chain rule, we get `f'(x) = d(sin(x))/dx = cos(x)`.
#
# ### <h4>Integral Calculus</h4>
#
# Integral calculus is the branch of calculus that deals with the study of accumulation of quantities. It is concerned with the study of integrals, which are used to measure the area under curves, volumes of solids, and other quantities.
#
# - **Integrals**: An integral is a measure of the accumulation of a function over a given interval. It is denoted by the symbol `∫` and is read as "the integral of."
# - **Rules of Integration**: There are several rules of integration that are used to find the integrals of functions. These include the power rule, substitution rule, and integration by parts.
#
# ### <h4>Examples of Integrals</h4>
#
# Let's consider some examples of integrals to illustrate the concept.
#
# - **Example 1**: Find the integral of the function `f(x) = 3x^2`.
# - **Solution**: Using the power rule, we get `∫3x^2 dx = x^3 + C`.
# - **Example 2**: Find the integral of the function `f(x) = sin(x)`.
# - **Solution**: Using the substitution rule, we get `∫sin(x) dx = -cos(x) + C`.
#
# ### <h4>Conclusion</h4>
#
# In this lesson, we introduced the basics of calculus, including the history, key concepts, differential calculus, and integral calculus. We also provided examples of derivatives and integrals to illustrate the concepts. In the next lesson, we will delve deeper into the topics of differential calculus and explore more advanced concepts.
#
# ### <h4>Exercises</h4>
#
# 1. Find the derivative of the function `f(x) = 2x^3`.
# 2. Find the integral of the function `f(x) = x^2`.
# 3. Find the derivative of the function `f(x) = sin(2x)`.
# 4. Find the integral of the function `f(x) = cos(x)`.
#
# ### <h4>References</h4>
#
# 1. "Calculus" by Michael Spivak
# 2. "Calculus: Early Transcendentals" by James Stewart
# 3. "Calculus" by David Guichard
#
# ### <h4>Additional Resources</h4>
#
# 1. Khan Academy: Calculus
# 2. MIT OpenCourseWare: Calculus
# 3. Wolfram Alpha: Calculus
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 2: History and Development of Calculus
#
# ### Lesson 2: History and Development of Calculus
#
# ### <h4>Introduction</h4>
# Calculus, a branch of mathematics that deals with the study of continuous change, has a rich and fascinating history that spans over 2,000 years. From ancient civilizations to modern mathematicians, the development of calculus has been a gradual process that has involved the contributions of many brilliant minds. In this lesson, we will explore the history and development of calculus, from its early beginnings to its modern applications.
#
# ### <h4>The Ancient Roots of Calculus</h4>
# <b>The word "calculus" comes from the Latin word "calculus," which means "pebble" or "small stone." This refers to the ancient practice of using pebbles or small stones to count and calculate.</b>
#
# The earliest known contributions to calculus date back to ancient civilizations in Egypt, Greece, and China. The Egyptians, for example, used arithmetic and geometric methods to calculate areas and volumes of shapes. The Greek mathematician Euclid (fl. 300 BCE) wrote extensively on geometry and developed the concept of infinitesimal quantities.
#
# ### <h4>The Development of Calculus in the Middle Ages</h4>
# During the Middle Ages, mathematicians such as Ibn al-Haytham (965-1040 CE) and Omar Khayyam (1048-1131 CE) made significant contributions to the development of calculus. Ibn al-Haytham, a Persian mathematician, wrote a book on optics that included a discussion of the concept of infinitesimal quantities. Omar Khayyam, a Persian poet and mathematician, developed a method for solving algebraic equations that involved the use of infinitesimal quantities.
#
# ### <h4>The Emergence of Modern Calculus</h4>
# The modern development of calculus began in the 17th century with the work of Sir Isaac Newton (1643-1727 CE) and German mathematician Gottfried Wilhelm Leibniz (1646-1716 CE). Newton developed the method of "fluxions," which is equivalent to the modern method of derivatives. Leibniz, on the other hand, developed the notation and formalism that we use today.
#
# ### <h4>Key Concepts in the Development of Calculus</h4>
# Some key concepts that played a crucial role in the development of calculus include:
#
# * <b>Infinitesimal quantities:</b> The concept of infinitesimal quantities, which refers to quantities that are smaller than any finite quantity but not zero.
# * <b>Limits:</b> The concept of limits, which refers to the behavior of a function as the input values approach a certain value.
# * <b>Derivatives:</b> The concept of derivatives, which refers to the rate of change of a function with respect to its input values.
# * <b>Integrals:</b> The concept of integrals, which refers to the accumulation of a function over a given interval.
#
# ### <h4>Examples and Applications</h4>
# Calculus has numerous applications in various fields, including physics, engineering, economics, and computer science. Some examples of applications include:
#
# * <b>Optimization problems:</b> Calculus is used to optimize functions, which is essential in fields such as economics and engineering.
# * <b>Physics and engineering:</b> Calculus is used to describe the motion of objects, including the acceleration and velocity of particles.
# * <b>Computer science:</b> Calculus is used in computer graphics, machine learning, and data analysis.
#
# ### <h4>Conclusion</h4>
# In conclusion, the history and development of calculus is a rich and fascinating story that spans over 2,000 years. From ancient civilizations to modern mathematicians, the development of calculus has been a gradual process that has involved the contributions of many brilliant minds. Calculus has numerous applications in various fields, including physics, engineering, economics, and computer science.
#
# ### <h4>Exercises and Problems</h4>
# 1. What is the definition of calculus?
# 2. Who are some of the key mathematicians who contributed to the development of calculus?
# 3. What are some of the key concepts in the development of calculus?
# 4. What are some of the applications of calculus in various fields?
#
# ### <h4>Solutions and Answers</h4>
# 1. Calculus is the study of continuous change.
# 2. Some of the key mathematicians who contributed to the development of calculus include Sir Isaac Newton, Gottfried Wilhelm Leibniz, Ibn al-Haytham, and Omar Khayyam.
# 3. Some of the key concepts in the development of calculus include infinitesimal quantities, limits, derivatives, and integrals.
# 4. Some of the applications of calculus in various fields include optimization problems, physics and engineering, and computer science.
#
# ### <h4>References</h4>
# * "A History of Mathematics" by Carl B. Boyer
# * "Calculus" by Michael Spivak
# * "The Calculus of Friendship" by Steven Strogatz
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 3: Basic Concepts and Terminology
#
# ### Lesson 3: Basic Concepts and Terminology in Calculus
#
# ### <h4>Introduction</h4>
# Calculus is a branch of mathematics that deals with the study of continuous change. It is a fundamental subject that has numerous applications in various fields such as physics, engineering, economics, and computer science. In this lesson, we will introduce the basic concepts and terminology of calculus.
#
# ### <h4>What is Calculus?</h4>
# Calculus is a mathematical discipline that involves the study of two main branches: Differential Calculus and Integral Calculus.
#
# - **Differential Calculus:** This branch deals with the study of rates of change and slopes of curves. It helps us to find the derivative of a function, which represents the rate of change of the function with respect to one of its variables.
#
# - **Integral Calculus:** This branch deals with the study of accumulation of quantities. It helps us to find the definite integral of a function, which represents the area under the curve of the function.
#
# ### <h4>Key Concepts in Calculus</h4>
# Some of the key concepts in calculus include:
#
# - **Limits:** The concept of limits is fundamental to calculus. It helps us to understand the behavior of a function as the input values approach a certain value.
#
# - **Derivatives:** Derivatives are used to measure the rate of change of a function with respect to one of its variables. They are denoted by the symbol 'dy/dx' or 'f'(x).
#
# - **Integrals:** Integrals are used to find the area under the curve of a function. They are denoted by the symbol ∫.
#
# - **Functions:** Functions are mathematical relations between variables. They are used to describe the relationship between the input and output values of a system.
#
# ### <h4>Types of Functions</h4>
# There are several types of functions in calculus, including:
#
# - **Polynomial Functions:** These are functions that involve only non-negative integer powers of the variable. Examples include f(x) = x^2 + 3x - 4 and f(x) = 2x^3 - 5x^2 + x + 1.
#
# - **Rational Functions:** These are functions that involve the ratio of two polynomials. Examples include f(x) = x^2 / (x + 1) and f(x) = (2x + 1) / (x - 1).
#
# - **Trigonometric Functions:** These are functions that involve the trigonometric ratios of angles. Examples include f(x) = sin(x) and f(x) = cos(x).
#
# - **Exponential Functions:** These are functions that involve the exponential of the variable. Examples include f(x) = e^x and f(x) = 2^x.
#
# ### <h4>Terminology in Calculus</h4>
# Some of the common terminology used in calculus includes:
#
# - **Domain:** The domain of a function is the set of all possible input values for which the function is defined.
#
# - **Range:** The range of a function is the set of all possible output values for which the function is defined.
#
# - **Independent Variable:** The independent variable is the variable that is being changed or varied in a function.
#
# - **Dependent Variable:** The dependent variable is the variable that is being measured or observed in a function.
#
# - **Slope:** The slope of a curve is a measure of how steep the curve is at a given point.
#
# - **Y-intercept:** The y-intercept of a curve is the point where the curve intersects the y-axis.
#
# ### <h4>Examples and Applications</h4>
# Calculus has numerous applications in various fields, including physics, engineering, economics, and computer science. Some examples of applications of calculus include:
#
# - **Motion of Objects:** Calculus is used to describe the motion of objects in terms of their position, velocity, and acceleration.
#
# - **Optimization:** Calculus is used to optimize functions, which is essential in fields such as economics and engineering.
#
# - **Area and Volume:** Calculus is used to find the area and volume of complex shapes, which is essential in fields such as architecture and engineering.
#
# - **Computer Science:** Calculus is used in computer science to develop algorithms and models for solving complex problems.
#
# ### <h4>Conclusion</h4>
# In this lesson, we introduced the basic concepts and terminology of calculus. We discussed the two main branches of calculus, differential calculus and integral calculus, and some of the key concepts in calculus, including limits, derivatives, and integrals. We also discussed the types of functions and some of the common terminology used in calculus. Finally, we provided some examples and applications of calculus in various fields.
#
# ### <h4>Exercises</h4>
# 1. Find the derivative of the function f(x) = 3x^2 + 2x - 5.
# 2. Find the definite integral of the function f(x) = x^2 + 1 from x = 0 to x = 1.
# 3. Find the area under the curve of the function f(x) = x^2 + 1 from x = 0 to x = 1.
# 4. Find the maximum value of the function f(x) = x^2 - 4x + 3.
# 5. Find the minimum value of the function f(x) = x^2 + 2x - 3.
#
# ### <h4>Solutions</h4>
# 1. The derivative of the function f(x) = 3x^2 + 2x - 5 is f'(x) = 6x + 2.
# 2. The definite integral of the function f(x) = x^2 + 1 from x = 0 to x = 1 is ∫(x^2 + 1) dx from 0 to 1 = (1/3)x^3 + x from 0 to 1 = (1/3)(1)^3 + 1 - (1/3)(0)^3 - 0 = 1 + 1/3 = 4/3.
# 3. The area under the curve of the function f(x) = x^2 + 1 from x = 0 to x = 1 is ∫(x^2 + 1) dx from 0 to 1 = (1/3)x^3 + x from 0 to 1 = (1/3)(1)^3 + 1 - (1/3)(0)^3 - 0 = 1 + 1/3 = 4/3.
# 4. The maximum value of the function f(x) = x^2 - 4x + 3 is f(2) = (2)^2 - 4(2) + 3 = 4 - 8 + 3 = -1.
# 5. The minimum value of the function f(x) = x^2 + 2x - 3 is f(-1) = (-1)^2 + 2(-1) - 3 = 1 - 2 - 3 = -4.
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 4: Limits and Continuity
#
# <h4>Lesson 4: Limits and Continuity</h4>
#
# <p>Calculus is a branch of mathematics that deals with the study of continuous change. In this lesson, we will explore the concept of limits and continuity, which are fundamental to understanding calculus.</p>
#
# <h4>What is a Limit?</h4>
#
# <p>A limit is a value that a function approaches as the input (or independent variable) gets arbitrarily close to a certain point. In other words, it is the value that the function gets arbitrarily close to as the input gets arbitrarily close to a certain point.</p>
#
# <p>Mathematically, a limit can be represented as:</p>
#
# <ul>
#   <li><b>lim x→a f(x) = L</b></li>
# </ul>
#
# <p>where:</p>
#
# <ul>
#   <li><b>f(x)</b> is the function</li>
#   <li><b>x</b> is the input (or independent variable)</li>
#   <li><b>a</b> is the point at which the limit is being evaluated</li>
#   <li><b>L</b> is the value that the function approaches as x gets arbitrarily close to a</li>
# </ul>
#
# <h4>Types of Limits</h4>
#
# <p>There are two types of limits: one-sided limits and two-sided limits.</p>
#
# <ul>
#   <li><b>One-sided limits:</b> These are limits that approach a point from one side only. For example, the limit as x approaches 0 from the right (x→0+) or the limit as x approaches 0 from the left (x→0-).</li>
#   <li><b>Two-sided limits:</b> These are limits that approach a point from both sides. For example, the limit as x approaches 0 (x→0).</li>
# </ul>
#
# <h4>Properties of Limits</h4>
#
# <p>There are several properties of limits that are useful to know:</p>
#
# <ul>
#   <li><b>Linearity:</b> The limit of a sum is the sum of the limits. For example, <b>lim x→a (f(x) + g(x)) = lim x→a f(x) + lim x→a g(x)</b></li>
#   <li><b>Homogeneity:</b> The limit of a product is the product of the limits. For example, <b>lim x→a (f(x) * g(x)) = lim x→a f(x) * lim x→a g(x)</b></li>
#   <li><b>Constant Multiple Rule:</b> The limit of a constant multiple is the constant multiple of the limit. For example, <b>lim x→a (c * f(x)) = c * lim x→a f(x)</b></li>
# </ul>
#
# <h4>Continuity</h4>
#
# <p>Continuity is a concept that is closely related to limits. A function is said to be continuous at a point if the limit of the function as x approaches that point is equal to the value of the function at that point.</p>
#
# <p>Mathematically, a function f(x) is continuous at a point a if:</p>
#
# <ul>
#   <li><b>lim x→a f(x) = f(a)</b></li>
# </ul>
#
# <h4>Types of Discontinuity</h4>
#
# <p>There are several types of discontinuity:</p>
#
# <ul>
#   <li><b>Removable discontinuity:</b> This occurs when the limit of the function as x approaches a point is equal to the value of the function at that point, but the function is not defined at that point.</li>
#   <li><b>Jump discontinuity:</b> This occurs when the limit of the function as x approaches a point from one side is not equal to the limit of the function as x approaches that point from the other side.</li>
#   <li><b>Infinite discontinuity:</b> This occurs when the limit of the function as x approaches a point is infinite.</li>
# </ul>
#
# <h4>Examples</h4>
#
# <p>Here are some examples of limits and continuity:</p>
#
# <ul>
#   <li><b>Example 1:</b> Find the limit as x approaches 0 of the function f(x) = x^2.</li>
#   <p><b>Solution:</b> The limit as x approaches 0 of the function f(x) = x^2 is 0, since the value of the function gets arbitrarily close to 0 as x gets arbitrarily close to 0.</p>
#   <li><b>Example 2:</b> Find the limit as x approaches 1 of the function f(x) = (x-1)/(x+1).</li>
#   <p><b>Solution:</b> The limit as x approaches 1 of the function f(x) = (x-1)/(x+1) is 1/2, since the value of the function gets arbitrarily close to 1/2 as x gets arbitrarily close to 1.</p>
#   <li><b>Example 3:</b> Find the limit as x approaches 0 of the function f(x) = 1/x.</li>
#   <p><b>Solution:</b> The limit as x approaches 0 of the function f(x) = 1/x is infinite, since the value of the function gets arbitrarily large as x gets arbitrarily close to 0.</p>
# </ul>
#
# <h4>Exercises</h4>
#
# <p>Here are some exercises to practice limits and continuity:</p>
#
# <ul>
#   <li>Find the limit as x approaches 2 of the function f(x) = x^2 - 4.</li>
#   <li>Find the limit as x approaches 0 of the function f(x) = sin(x)/x.</li>
#   <li>Find the limit as x approaches 1 of the function f(x) = (x-1)/(x+1).</li>
# </ul>
#
# <h4>Conclusion</h4>
#
# <p>In this lesson, we have explored the concept of limits and continuity. We have seen how limits can be used to evaluate the behavior of functions as the input gets arbitrarily close to a certain point. We have also seen how continuity is a concept that is closely related to limits, and how it can be used to determine whether a function is continuous at a point.</p>
#
# <p>With practice and experience, you will become more comfortable with limits and continuity, and you will be able to apply these concepts to a wide range of problems in calculus and other areas of mathematics.</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 5: Evaluating Limits
#
# <h4>Lesson 5: Evaluating Limits</h4>
#
# <p>In this lesson, we will learn about evaluating limits, which is a fundamental concept in calculus. Limits are used to study the behavior of functions as the input values approach a certain point. We will cover the different types of limits, how to evaluate them, and some important theorems related to limits.</p>
#
# <h4>Types of Limits</h4>
#
# <p>There are two main types of limits: one-sided limits and two-sided limits.</p>
#
# <ul>
#   <li><b>One-Sided Limits:</b> These are limits that approach a point from one side only. For example, the limit as x approaches 0 from the right (0+) or the limit as x approaches 0 from the left (0-).</li>
#   <li><b>Two-Sided Limits:</b> These are limits that approach a point from both sides. For example, the limit as x approaches 0.</li>
# </ul>
#
# <h4>Evaluating Limits</h4>
#
# <p>To evaluate a limit, we need to determine the value that the function approaches as the input values get arbitrarily close to a certain point. There are several methods to evaluate limits, including:</p>
#
# <ul>
#   <li><b>Direct Substitution:</b> This method involves substituting the value of the point into the function and evaluating the result.</li>
#   <li><b>Factoring:</b> This method involves factoring the numerator and denominator of the function and canceling out any common factors.</li>
#   <li><b>Canceling Out:</b> This method involves canceling out any common factors in the numerator and denominator of the function.</li>
#   <li><b>Using the Squeeze Theorem:</b> This method involves using the squeeze theorem to evaluate the limit of a function that is sandwiched between two other functions.</li>
# </ul>
#
# <h4>Important Theorems Related to Limits</h4>
#
# <p>There are several important theorems related to limits that we need to know:</p>
#
# <ul>
#   <li><b>The Squeeze Theorem:</b> This theorem states that if a function f(x) is sandwiched between two other functions g(x) and h(x), and the limits of g(x) and h(x) as x approaches a point are equal, then the limit of f(x) as x approaches that point is also equal.</li>
#   <li><b>The Sandwich Theorem:</b> This theorem states that if a function f(x) is sandwiched between two other functions g(x) and h(x), and the limits of g(x) and h(x) as x approaches a point are equal, then the limit of f(x) as x approaches that point is also equal.</li>
#   <li><b>The Limit Laws:</b> These laws state that the limit of a sum, difference, product, or quotient of functions is equal to the sum, difference, product, or quotient of the limits of the individual functions.</li>
# </ul>
#
# <h4>Examples</h4>
#
# <p>Here are some examples of evaluating limits:</p>
#
# <ul>
#   <li><b>Example 1:</b> Evaluate the limit as x approaches 0 of (x^2 + 3x - 4) / (x + 2).</li>
#   <li><b>Example 2:</b> Evaluate the limit as x approaches 1 of (x^2 - 4) / (x - 1).</li>
#   <li><b>Example 3:</b> Evaluate the limit as x approaches 0 of (sin(x)) / x.</li>
# </ul>
#
# <h4>Solutions</h4>
#
# <p>Here are the solutions to the examples:</p>
#
# <ul>
#   <li><b>Example 1:</b> Using direct substitution, we get (0^2 + 3(0) - 4) / (0 + 2) = -4/2 = -2.</li>
#   <li><b>Example 2:</b> Using factoring, we get ((x - 2)(x + 2)) / (x - 1). Canceling out the common factor (x + 2), we get (x - 2) / (x - 1). Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) = -1/0, which is undefined. However, we can use the limit laws to evaluate the limit. The limit of (x - 2) / (x - 1) as x approaches 1 is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the right, which is equal to the limit of (x - 2) / (x - 1) as x approaches 1 from the left. Using direct substitution, we get (1 - 2) / (1 - 1) ...
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 6: Properties of Limits
#
# <h4>Lesson 6: Properties of Limits</h4>
#
# <p>In this lesson, we will explore the properties of limits, which are essential in understanding and working with functions in calculus. The properties of limits will help us simplify complex functions and make them easier to work with.</p>
#
# <h4>1. The Sum Property of Limits</h4>
#
# <p>The sum property of limits states that the limit of a sum is equal to the sum of the limits. Mathematically, this can be expressed as:</p>
#
# <ul>
#   <li><b>lim (x→a) [f(x) + g(x)] = lim (x→a) f(x) + lim (x→a) g(x)</b></li>
# </ul>
#
# <p>Let's consider an example to illustrate this property.</p>
#
# <p>Example 1:</p>
#
# <p>Find the limit of the function f(x) = 2x^2 + 3x - 1 as x approaches 2.</p>
#
# <p>Solution:</p>
#
# <p>Using the sum property of limits, we can rewrite the function as:</p>
#
# <p>lim (x→2) [2x^2 + 3x - 1] = lim (x→2) 2x^2 + lim (x→2) 3x - lim (x→2) 1</p>
#
# <p>Now, we can evaluate each limit separately:</p>
#
# <p>lim (x→2) 2x^2 = 2(2)^2 = 8</p>
#
# <p>lim (x→2) 3x = 3(2) = 6</p>
#
# <p>lim (x→2) 1 = 1</p>
#
# <p>Substituting these values back into the original equation, we get:</p>
#
# <p>lim (x→2) [2x^2 + 3x - 1] = 8 + 6 - 1 = 13</p>
#
# <h4>2. The Product Property of Limits</h4>
#
# <p>The product property of limits states that the limit of a product is equal to the product of the limits. Mathematically, this can be expressed as:</p>
#
# <ul>
#   <li><b>lim (x→a) [f(x) * g(x)] = lim (x→a) f(x) * lim (x→a) g(x)</b></li>
# </ul>
#
# <p>Let's consider an example to illustrate this property.</p>
#
# <p>Example 2:</p>
#
# <p>Find the limit of the function f(x) = (2x - 1)(3x + 2) as x approaches 2.</p>
#
# <p>Solution:</p>
#
# <p>Using the product property of limits, we can rewrite the function as:</p>
#
# <p>lim (x→2) [(2x - 1)(3x + 2)] = lim (x→2) (2x - 1) * lim (x→2) (3x + 2)</p>
#
# <p>Now, we can evaluate each limit separately:</p>
#
# <p>lim (x→2) (2x - 1) = 2(2) - 1 = 3</p>
#
# <p>lim (x→2) (3x + 2) = 3(2) + 2 = 8</p>
#
# <p>Substituting these values back into the original equation, we get:</p>
#
# <p>lim (x→2) [(2x - 1)(3x + 2)] = 3 * 8 = 24</p>
#
# <h4>3. The Chain Rule of Limits</h4>
#
# <p>The chain rule of limits states that the limit of a composite function is equal to the composite of the limits. Mathematically, this can be expressed as:</p>
#
# <ul>
#   <li><b>lim (x→a) f(g(x)) = f(lim (x→a) g(x))</b></li>
# </ul>
#
# <p>Let's consider an example to illustrate this property.</p>
#
# <p>Example 3:</p>
#
# <p>Find the limit of the function f(x) = sin(x^2) as x approaches 2.</p>
#
# <p>Solution:</p>
#
# <p>Using the chain rule of limits, we can rewrite the function as:</p>
#
# <p>lim (x→2) sin(x^2) = sin(lim (x→2) x^2)</p>
#
# <p>Now, we can evaluate the inner limit:</p>
#
# <p>lim (x→2) x^2 = (2)^2 = 4</p>
#
# <p>Substituting this value back into the original equation, we get:</p>
#
# <p>lim (x→2) sin(x^2) = sin(4)</p>
#
# <h4>4. The Constant Multiple Property of Limits</h4>
#
# <p>The constant multiple property of limits states that the limit of a constant multiple of a function is equal to the constant multiple of the limit. Mathematically, this can be expressed as:</p>
#
# <ul>
#   <li><b>lim (x→a) [c * f(x)] = c * lim (x→a) f(x)</b></li>
# </ul>
#
# <p>Let's consider an example to illustrate this property.</p>
#
# <p>Example 4:</p>
#
# <p>Find the limit of the function f(x) = 3x^2 as x approaches 2.</p>
#
# <p>Solution:</p>
#
# <p>Using the constant multiple property of limits, we can rewrite the function as:</p>
#
# <p>lim (x→2) [3x^2] = 3 * lim (x→2) x^2</p>
#
# <p>Now, we can evaluate the inner limit:</p>
#
# <p>lim (x→2) x^2 = (2)^2 = 4</p>
#
# <p>Substituting this value back into the original equation, we get:</p>
#
# <p>lim (x→2) [3x^2] = 3 * 4 = 12</p>
#
# <h4>Conclusion</h4>
#
# <p>In this lesson, we have explored the properties of limits, including the sum property, product property, chain rule, and constant multiple property. These properties are essential in understanding and working with functions in calculus and will help us simplify complex functions and make them easier to work with.</p>
#
# <h4>Practice Problems</h4>
#
# <p>1. Find the limit of the function f(x) = 2x^2 + 3x - 1 as x approaches 2.</p>
#
# <p>2. Find the limit of the function f(x) = (2x - 1)(3x + 2) as x approaches 2.</p>
#
# <p>3. Find the limit of the function f(x) = sin(x^2) as x approaches 2.</p>
#
# <p>4. Find the limit of the function f(x) = 3x^2 as x approaches 2.</p>
#
# <p>Answers:</p>
#
# <p>1. 13</p>
#
# <p>2. 24</p>
#
# <p>3. sin(4)</p>
#
# <p>4. 12</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 7: Squeeze Theorem and Infinite Limits
#
# <p>Error generating content: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jn09qcw3e1avgw2q9vxda0gz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5912, Requested 272. Please try again in 1.839999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 8: Introduction to Derivatives
#
# <h4>Lesson 8: Introduction to Derivatives</h4>
#
# <p>Derivatives are a fundamental concept in calculus, and they play a crucial role in understanding various phenomena in physics, engineering, and economics. In this lesson, we will introduce the concept of derivatives, explore their significance, and learn how to calculate them.</p>
#
# <h4>What are Derivatives?</h4>
#
# <p>A derivative measures the rate of change of a function with respect to one of its variables. It represents the instantaneous rate of change of the function at a given point. In other words, it tells us how fast the output of a function changes when we change the input.</p>
#
# <h4>Notation and Terminology</h4>
#
# <p>The derivative of a function f(x) with respect to x is denoted by f'(x) or (df/dx)(x). The derivative represents the rate of change of the function at a point x. The process of finding the derivative is called differentiation.</p>
#
# <h4>Geometric Interpretation</h4>
#
# <p>The derivative of a function can be interpreted geometrically as the slope of the tangent line to the graph of the function at a given point. The tangent line is a line that just touches the graph of the function at a single point and has the same slope as the function at that point.</p>
#
# <h4>Physical Interpretation</h4>
#
# <p>The derivative of a function can be interpreted physically as the rate of change of a quantity with respect to time or another variable. For example, if we have a function that represents the position of an object with respect to time, the derivative of the function represents the velocity of the object.</p>
#
# <h4>Types of Derivatives</h4>
#
# <ul>
#   <li><b>First Derivative:</b> The first derivative of a function represents the rate of change of the function at a given point.</li>
#   <li><b>Second Derivative:</b> The second derivative of a function represents the rate of change of the first derivative at a given point.</li>
#   <li><b>Higher-Order Derivatives:</b> Higher-order derivatives are derivatives of higher order than the first derivative.</li>
# </ul>
#
# <h4>Rules of Differentiation</h4>
#
# <p>There are several rules of differentiation that we need to learn in order to calculate derivatives. These rules include:</p>
#
# <ul>
#   <li><b>Power Rule:</b> If f(x) = x^n, then f'(x) = nx^(n-1)</li>
#   <li><b>Product Rule:</b> If f(x) = u(x)v(x), then f'(x) = u'(x)v(x) + u(x)v'(x)</li>
#   <li><b>Quotient Rule:</b> If f(x) = u(x)/v(x), then f'(x) = (u'(x)v(x) - u(x)v'(x)) / v(x)^2</li>
#   <li><b>Chain Rule:</b> If f(x) = g(h(x)), then f'(x) = g'(h(x)) \* h'(x)</li>
# </ul>
#
# <h4>Examples</h4>
#
# <p>Let's consider some examples to illustrate the concept of derivatives.</p>
#
# <p>Example 1: Find the derivative of f(x) = 3x^2 + 2x - 5</p>
#
# <p>Using the power rule, we get:</p>
#
# <p>f'(x) = d(3x^2)/dx + d(2x)/dx - d(5)/dx</p>
#
# <p>f'(x) = 6x + 2</p>
#
# <p>Example 2: Find the derivative of f(x) = (2x + 1)/(x - 1)</p>
#
# <p>Using the quotient rule, we get:</p>
#
# <p>f'(x) = ((d(2x + 1)/dx)(x - 1) - (2x + 1)(d(x - 1)/dx)) / (x - 1)^2</p>
#
# <p>f'(x) = (2(x - 1) - (2x + 1)(1)) / (x - 1)^2</p>
#
# <p>f'(x) = (-3) / (x - 1)^2</p>
#
# <h4>Conclusion</h4>
#
# <p>In this lesson, we introduced the concept of derivatives, explored their significance, and learned how to calculate them. We also discussed the notation and terminology, geometric and physical interpretations, types of derivatives, and rules of differentiation. We used examples to illustrate the concept of derivatives and applied the rules of differentiation to calculate derivatives.</p>
#
# <h4>Exercises</h4>
#
# <p>Try the following exercises to practice what you have learned:</p>
#
# <ul>
#   <li>Find the derivative of f(x) = x^3 - 2x^2 + 3x - 1</li>
#   <li>Find the derivative of f(x) = (x^2 + 1)/(x + 1)</li>
#   <li>Find the second derivative of f(x) = x^2 + 2x - 1</li>
# </ul>
#
# <h4>Assessment</h4>
#
# <p>Assessment will be based on the exercises and problems you complete. Make sure to show your work and explain your reasoning.</p>
#
# <h4>Next Lesson</h4>
#
# <p>The next lesson will cover the application of derivatives in physics and engineering. We will learn how to use derivatives to model real-world phenomena and solve problems.</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 9: Definition of a Derivative
#
# <h4>Lesson 9: Definition of a Derivative</h4>
#
# <p>In this lesson, we will explore the concept of a derivative, which is a fundamental concept in calculus. The derivative of a function represents the rate of change of the function with respect to one of its variables. It is a measure of how fast the output of a function changes when one of its inputs changes.</p>
#
# <h4>What is a Derivative?</h4>
#
# <p>A derivative is a mathematical concept that measures the rate of change of a function with respect to one of its variables. It is denoted by the symbol <b>f'(x)</b> or <b>dy/dx</b>. The derivative of a function <b>f(x)</b> is a new function that represents the rate of change of <b>f(x)</b> with respect to <b>x</b>.</p>
#
# <h4>Geometric Interpretation of a Derivative</h4>
#
# <p>The derivative of a function can be interpreted geometrically as the slope of the tangent line to the graph of the function at a given point. The tangent line is a line that just touches the graph of the function at a single point and has the same slope as the function at that point.</p>
#
# <h4>Mathematical Definition of a Derivative</h4>
#
# <p>The derivative of a function <b>f(x)</b> is defined as:</p>
#
# <b>f'(x) = lim(h → 0) [f(x + h) - f(x)]/h</b>
#
# <p>This definition states that the derivative of a function is the limit of the difference quotient as the change in <b>x</b> approaches zero. The difference quotient is the ratio of the change in <b>f(x)</b> to the change in <b>x</b>.</p>
#
# <h4>Properties of Derivatives</h4>
#
# <p>Derivatives have several important properties that make them useful in calculus. Some of these properties include:</p>
#
# <ul>
#   <li><b>Linearity**: The derivative of a sum of functions is the sum of their derivatives.</li>
#   <li><b>Product Rule**: The derivative of a product of two functions is the derivative of the first function times the second function plus the first function times the derivative of the second function.</li>
#   <li><b>Quotient Rule**: The derivative of a quotient of two functions is the derivative of the numerator times the denominator minus the numerator times the derivative of the denominator, all divided by the square of the denominator.</li>
# </ul>
#
# <h4>Examples of Derivatives</h4>
#
# <p>Here are a few examples of derivatives:</p>
#
# <ul>
#   <li><b>f(x) = x^2</b>: The derivative of <b>f(x) = x^2</b> is <b>f'(x) = 2x</b>.</li>
#   <li><b>f(x) = sin(x)</b>: The derivative of <b>f(x) = sin(x)</b> is <b>f'(x) = cos(x)</b>.</li>
#   <li><b>f(x) = e^x</b>: The derivative of <b>f(x) = e^x</b> is <b>f'(x) = e^x</b>.</li>
# </ul>
#
# <h4>Conclusion</h4>
#
# <p>In this lesson, we have explored the concept of a derivative, which is a fundamental concept in calculus. We have seen the geometric interpretation of a derivative, the mathematical definition of a derivative, and some of the important properties of derivatives. We have also seen some examples of derivatives. Derivatives are used to model real-world phenomena and are an essential tool in many fields, including physics, engineering, and economics.</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 10: Rules of Differentiation
#
# <p>Error generating content: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jn09qcw3e1avgw2q9vxda0gz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5847, Requested 269. Please try again in 1.16s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 11: Power Rule and Product Rule
#
# <p>Error generating content: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jn09qcw3e1avgw2q9vxda0gz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5819, Requested 270. Please try again in 890ms. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 12: Quotient Rule and Chain Rule
#
# <p>Error generating content: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jn09qcw3e1avgw2q9vxda0gz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5783, Requested 272. Please try again in 550ms. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 13: Implicit Differentiation
#
# <h4>Lesson 13: Implicit Differentiation</h4>
#
# <p>Implicit differentiation is a technique used to find the derivative of an implicitly defined function. An implicitly defined function is a function where the variable is not isolated on one side of the equation. In this lesson, we will learn how to use implicit differentiation to find the derivative of such functions.</p>
#
# <h4>What is Implicit Differentiation?</h4>
#
# <p>Implicit differentiation is a method used to find the derivative of an implicitly defined function. It is called "implicit" because the variable is not isolated on one side of the equation. The main idea behind implicit differentiation is to differentiate both sides of the equation with respect to the variable, while treating the other variables as constants.</p>
#
# <h4>Steps for Implicit Differentiation</h4>
#
# <p>The steps for implicit differentiation are as follows:</p>
#
# <ul>
#   <li>Differentiate both sides of the equation with respect to the variable.</li>
#   <li>Treat the other variables as constants.</li>
#   <li>Use the chain rule to differentiate the composite functions.</li>
#   <li>Simplify the resulting equation.</li>
# </ul>
#
# <h4>Example 1: Differentiating a Circle</h4>
#
# <p>Find the derivative of the equation of a circle: x^2 + y^2 = 1.</p>
#
# <p>Step 1: Differentiate both sides of the equation with respect to x.</p>
#
# <p>y^2 + 2xy(dy/dx) = 0</p>
#
# <p>Step 2: Treat y as a constant.</p>
#
# <p>y^2 + 2xy(dy/dx) = 0</p>
#
# <p>Step 3: Use the chain rule to differentiate the composite function y^2.</p>
#
# <p>y^2 + 2xy(dy/dx) = 0</p>
#
# <p>Step 4: Simplify the resulting equation.</p>
#
# <p>dy/dx = -y / x</p>
#
# <h4>Example 2: Differentiating an Ellipse</h4>
#
# <p>Find the derivative of the equation of an ellipse: x^2/a^2 + y^2/b^2 = 1.</p>
#
# <p>Step 1: Differentiate both sides of the equation with respect to x.</p>
#
# <p>2x/a^2 + 2y/b^2(dy/dx) = 0</p>
#
# <p>Step 2: Treat y as a constant.</p>
#
# <p>2x/a^2 + 2y/b^2(dy/dx) = 0</p>
#
# <p>Step 3: Use the chain rule to differentiate the composite function y^2.</p>
#
# <p>2x/a^2 + 2y/b^2(dy/dx) = 0</p>
#
# <p>Step 4: Simplify the resulting equation.</p>
#
# <p>dy/dx = -b^2x / a^2y</p>
#
# <h4>Proof of Implicit Differentiation</h4>
#
# <p>Let's consider a function f(x,y) = 0. We can write this function as:</p>
#
# <p>f(x,y) = 0</p>
#
# <p>Now, let's differentiate both sides of the equation with respect to x.</p>
#
# <p>d/dx(f(x,y)) = d/dx(0)</p>
#
# <p>Using the chain rule, we get:</p>
#
# <p>f_x(x,y) + f_y(x,y)(dy/dx) = 0</p>
#
# <p>where f_x(x,y) and f_y(x,y) are the partial derivatives of f(x,y) with respect to x and y, respectively.</p>
#
# <p>Solving for dy/dx, we get:</p>
#
# <p>dy/dx = -(f_x(x,y)) / (f_y(x,y))</p>
#
# <p>This is the formula for implicit differentiation.</p>
#
# <h4>Conclusion</h4>
#
# <p>In this lesson, we learned how to use implicit differentiation to find the derivative of an implicitly defined function. We saw two examples of how to use implicit differentiation to find the derivative of a circle and an ellipse. We also proved the formula for implicit differentiation.</p>
#
# <p>Implicit differentiation is a powerful tool that can be used to find the derivative of many types of functions. It is an important concept in calculus and is used extensively in physics, engineering, and other fields.</p>
#
# <h4>Exercises</h4>
#
# <p>1. Find the derivative of the equation of a parabola: x^2 + 2y = 1.</p>
#
# <p>2. Find the derivative of the equation of an ellipse: x^2/a^2 + y^2/b^2 = 1.</p>
#
# <p>3. Find the derivative of the equation of a hyperbola: x^2/a^2 - y^2/b^2 = 1.</p>
#
# <p>4. Find the derivative of the equation of a circle: x^2 + y^2 = 1.</p>
#
# <p>5. Find the derivative of the equation of an ellipse: x^2/a^2 + y^2/b^2 = 1.</p>
#
# <h4>Answers</h4>
#
# <p>1. dy/dx = -1.</p>
#
# <p>2. dy/dx = -b^2x / a^2y.</p>
#
# <p>3. dy/dx = b^2y / a^2x.</p>
#
# <p>4. dy/dx = -y / x.</p>
#
# <p>5. dy/dx = -b^2x / a^2y.</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 14: Higher-Order Derivatives
#
# <p>Error generating content: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jn09qcw3e1avgw2q9vxda0gz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5800, Requested 271. Please try again in 710ms. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 15: Applications of Derivatives
#
# <p>Error generating content: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jn09qcw3e1avgw2q9vxda0gz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5882, Requested 270. Please try again in 1.52s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}</p>
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 16: Introduction to Integrals
#
# <h4>Lesson 16: Introduction to Integrals</h4>
#
# <h5>Introduction</h5>
# <p>In the previous lessons, we have learned about the concept of limits and derivatives. However, these concepts are not enough to solve all types of problems in calculus. To solve problems involving accumulation of quantities, we need to learn about integrals. In this lesson, we will introduce the concept of integrals and learn how to evaluate them.</p>
#
# <h5>What is an Integral?</h5>
# <p>An integral is a mathematical operation that represents the accumulation of a quantity over a defined interval. It is denoted by the symbol ∫ and is used to find the area under a curve, the volume of a solid, and other quantities. The integral of a function f(x) with respect to x is denoted by ∫f(x)dx.</p>
#
# <h5>Types of Integrals</h5>
# ...
#
# 1. Initialize an array of size n.
# 2. Iterate over the array and perform a constant-time operation for each element.
# 3. Iterate over the array again and perform a constant-time operation for each element.
# 4. Return the result.
#
# Answer Key:
#
# 1. The maximum value of the function f(x) is 3, which occurs at x = 1.
# 2. The time it takes for the ball to hit the ground is 1.02 s.
# 3. The time complexity of the algorithm is O(n^2).
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 49: Advanced Topics in Calculus
#
# ### Lesson 49: Advanced Topics in Calculus
#
# #### Introduction
#
# Calculus is a branch of mathematics that deals with the study of continuous change. It has two main branches: Differential Calculus and Integral Calculus. In this lesson, we will explore some advanced topics in calculus, including the Mean Value Theorem, the Fundamental Theorem of Calculus, and the Taylor Series.
#
# #### The Mean Value Theorem
#
# The Mean Value Theorem is a fundamental theorem in calculus that states that if a function f(x) is continuous on the closed interval [a, b] and differentiable on the open interval (a, b), then there exists a point c in (a, b) such that:
#
# f'(c) = (f(b) - f(a)) / (b - a)
#
# This theorem is a generalization of the concept of the slope of a line. It states that if a function is continuous and differentiable on an interval, then there exists a point on that interval where the slope of the tangent line is equal to the average rate of change of the function over that interval.
#
# **Proof of the Mean Value Theorem**
#
# Let f(x) be a function that is continuous on [a, b] and differentiable on (a, b). We want to show that there exists a point c in (a, b) such that f'(c) = (f(b) - f(a)) / (b - a).
#
# We can start by defining a new function g(x) = f(x) - (f(b) - f(a)) / (b - a) (x - a). This function is continuous on [a, b] and differentiable on (a, b).
#
# By the Extreme Value Theorem, g(x) has a maximum or minimum value on [a, b]. Suppose that g(x) has a maximum value at x = c. Then, g'(c) = 0.
#
# Using the chain rule, we can find the derivative of g(x):
#
# g'(x) = f'(x) - (f(b) - f(a)) / (b - a)
#
# Evaluating this at x = c, we get:
#
# g'(c) = f'(c) - (f(b) - f(a)) / (b - a) = 0
#
# Solving for f'(c), we get:
#
# f'(c) = (f(b) - f(a)) / (b - a)
#
# This shows that there exists a point c in (a, b) such that f'(c) = (f(b) - f(a)) / (b - a), which is the Mean Value Theorem.
#
# #### The Fundamental Theorem of Calculus
#
# The Fundamental Theorem of Calculus is a fundamental theorem in calculus that states that differentiation and integration are inverse processes. It states that if f(x) is a continuous function on [a, b] and F(x) is the antiderivative of f(x), then:
#
# ∫[a, b] f(x) dx = F(b) - F(a)
#
# This theorem is a generalization of the concept of the area under a curve. It states that the definite integral of a function over an interval is equal to the difference between the antiderivative of the function evaluated at the endpoints of the interval.
#
# **Proof of the Fundamental Theorem of Calculus**
#
# Let f(x) be a continuous function on [a, b] and F(x) be the antiderivative of f(x). We want to show that ∫[a, b] f(x) dx = F(b) - F(a).
#
# We can start by defining a new function G(x) = ∫[a, x] f(t) dt. This function is continuous on [a, b].
#
# Using the definition of the derivative, we can find the derivative of G(x):
#
# G'(x) = f(x)
#
# Using the chain rule, we can find the derivative of F(x):
#
# F'(x) = f(x)
#
# Since F(x) is the antiderivative of f(x), we know that F'(x) = f(x).
#
# Evaluating this at x = b, we get:
#
# F'(b) = f(b)
#
# Evaluating G'(x) at x = b, we get:
#
# G'(b) = f(b)
#
# Since G'(x) = f(x), we know that G'(b) = f(b).
#
# Equating these two expressions, we get:
#
# F'(b) = G'(b)
#
# Solving for G(b), we get:
#
# G(b) = F(b) + C
#
# where C is a constant.
#
# Evaluating G(x) at x = a, we get:
#
# G(a) = ∫[a, a] f(t) dt = 0
#
# Substituting this into the expression for G(b), we get:
#
# G(b) = F(b) + C
#
# Substituting this into the expression for G(b), we get:
#
# ∫[a, b] f(x) dx = F(b) - F(a)
#
# This shows that the definite integral of a function over an interval is equal to the difference between the antiderivative of the function evaluated at the endpoints of the interval, which is the Fundamental Theorem of Calculus.
#
# #### The Taylor Series
#
# The Taylor Series is a mathematical representation of a function as an infinite sum of terms. It is a powerful tool for approximating functions and is used extensively in mathematics, physics, and engineering.
#
# The Taylor Series of a function f(x) is given by:
#
# f(x) = f(a) + f'(a)(x - a) + f''(a)(x - a)^2 / 2! + f'''(a)(x - a)^3 / 3! + ...
#
# where a is a point in the domain of the function and f'(a), f''(a), f'''(a), ... are the derivatives of the function evaluated at a.
#
# **Proof of the Taylor Series**
#
# Let f(x) be a function that is infinitely differentiable at a point a in its domain. We want to show that the Taylor Series of f(x) is given by:
#
# f(x) = f(a) + f'(a)(x - a) + f''(a)(x - a)^2 / 2! + f'''(a)(x - a)^3 / 3! + ...
#
# We can start by defining a new function g(x) = f(x) - (f(a) + f'(a)(x - a) + f''(a)(x - a)^2 / 2! + f'''(a)(x - a)^3 / 3! + ...).
#
# This function is infinitely differentiable at a.
#
# Using the definition of the derivative, we can find the derivative of g(x):
#
# g'(x) = f'(x) - (f'(a) + f''(a)(x - a) + f'''(a)(x - a)^2 / 2! + f''''(a)(x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g'(a) = 0
#
# Using the definition of the derivative again, we can find the second derivative of g(x):
#
# g''(x) = f''(x) - (f''(a) + f'''(a)(x - a) + f''''(a)(x - a)^2 / 2! + f'''''(a)(x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g''(a) = 0
#
# Continuing this process, we can find the third derivative of g(x):
#
# g'''(x) = f'''(x) - (f'''(a) + f''''(a)(x - a) + f'''''(a)(x - a)^2 / 2! + f''''''(a)(x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g'''(a) = 0
#
# Continuing this process, we can find the nth derivative of g(x):
#
# g^(n)(x) = f^(n)(x) - (f^(n)(a) + f^(n+1)(a)(x - a) + f^(n+2)(a)(x - a)^2 / 2! + f^(n+3)(a)(x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g^(n)(a) = 0
#
# Since g(x) is infinitely differentiable at a, we know that g^(n)(a) = 0 for all n.
#
# Using the definition of the Taylor Series, we can write:
#
# g(x) = g(a) + g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ...
#
# Since g(a) = 0, we can simplify this to:
#
# g(x) = g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ...
#
# Continuing this process, we can write:
#
# g(x) = g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ... + g^(n)(a)(x - a)^n / n! + ...
#
# Since g^(n)(a) = 0 for all n, we can simplify this to:
#
# g(x) = 0
#
# This shows that the Taylor Series of f(x) is given by:
#
# f(x) = f(a) + f'(a)(x - a) + f''(a)(x - a)^2 / 2! + f'''(a)(x - a)^3 / 3! + ...
#
# This is a powerful tool for approximating functions and is used extensively in mathematics, physics, and engineering.
#
# #### Conclusion
#
# In this lesson, we have explored some advanced topics in calculus, including the Mean Value Theorem, the Fundamental Theorem of Calculus, and the Taylor Series. These theorems are fundamental to the study of calculus and have numerous applications in mathematics, physics, and engineering.
#
# The Mean Value Theorem states that if a function f(x) is continuous on the closed interval [a, b] and differentiable on the open interval (a, b), then there exists a point c in (a, b) such that f'(c) = (f(b) - f(a)) / (b - a).
#
# The Fundamental Theorem of Calculus states that differentiation and integration are inverse processes. It states that if f(x) is a continuous function on [a, b] and F(x) is the antiderivative of f(x), then ∫[a, b] f(x) dx = F(b) - F(a).
#
# The Taylor Series is a mathematical representation of a function as an infinite sum of terms. It is a powerful tool for approximating functions and is used extensively in mathematics, physics, and engineering.
#
# These theorems are fundamental to the study of calculus and have numerous applications in mathematics, physics, and engineering. They are used to solve problems in a wide range of fields, including physics, engineering, economics, and computer science.
#
# #### Exercises
#
# 1. Prove the Mean Value Theorem using the definition of the derivative.
# 2. Prove the Fundamental Theorem of Calculus using the definition of the definite integral.
# 3. Find the Taylor Series of the function f(x) = e^x.
# 4. Find the Taylor Series of the function f(x) = sin(x).
# 5. Use the Taylor Series to approximate the value of the function f(x) = e^x at x = 2.
#
# #### Solutions
#
# 1. The Mean Value Theorem can be proved using the definition of the derivative as follows:
#
# Let f(x) be a function that is continuous on the closed interval [a, b] and differentiable on the open interval (a, b). We want to show that there exists a point c in (a, b) such that f'(c) = (f(b) - f(a)) / (b - a).
#
# We can start by defining a new function g(x) = f(x) - (f(b) - f(a)) / (b - a) (x - a). This function is continuous on [a, b] and differentiable on (a, b).
#
# Using the definition of the derivative, we can find the derivative of g(x):
#
# g'(x) = f'(x) - (f(b) - f(a)) / (b - a)
#
# Evaluating this at x = c, we get:
#
# g'(c) = f'(c) - (f(b) - f(a)) / (b - a) = 0
#
# Solving for f'(c), we get:
#
# f'(c) = (f(b) - f(a)) / (b - a)
#
# This shows that there exists a point c in (a, b) such that f'(c) = (f(b) - f(a)) / (b - a), which is the Mean Value Theorem.
#
# 2. The Fundamental Theorem of Calculus can be proved using the definition of the definite integral as follows:
#
# Let f(x) be a continuous function on [a, b] and F(x) be the antiderivative of f(x). We want to show that ∫[a, b] f(x) dx = F(b) - F(a).
#
# We can start by defining a new function G(x) = ∫[a, x] f(t) dt. This function is continuous on [a, b].
#
# Using the definition of the derivative, we can find the derivative of G(x):
#
# G'(x) = f(x)
#
# Using the chain rule, we can find the derivative of F(x):
#
# F'(x) = f(x)
#
# Since F(x) is the antiderivative of f(x), we know that F'(x) = f(x).
#
# Evaluating this at x = b, we get:
#
# F'(b) = f(b)
#
# Evaluating G'(x) at x = b, we get:
#
# G'(b) = f(b)
#
# Since G'(x) = f(x), we know that G'(b) = f(b).
#
# Equating these two expressions, we get:
#
# F'(b) = G'(b)
#
# Solving for G(b), we get:
#
# G(b) = F(b) + C
#
# where C is a constant.
#
# Evaluating G(x) at x = a, we get:
#
# G(a) = ∫[a, a] f(t) dt = 0
#
# Substituting this into the expression for G(b), we get:
#
# G(b) = F(b) + C
#
# Substituting this into the expression for G(b), we get:
#
# ∫[a, b] f(x) dx = F(b) - F(a)
#
# This shows that the definite integral of a function over an interval is equal to the difference between the antiderivative of the function evaluated at the endpoints of the interval, which is the Fundamental Theorem of Calculus.
#
# 3. The Taylor Series of the function f(x) = e^x is given by:
#
# f(x) = e^a + e^a (x - a) + e^a (x - a)^2 / 2! + e^a (x - a)^3 / 3! + ...
#
# This can be proved using the definition of the Taylor Series as follows:
#
# Let f(x) = e^x. We want to show that the Taylor Series of f(x) is given by:
#
# f(x) = e^a + e^a (x - a) + e^a (x - a)^2 / 2! + e^a (x - a)^3 / 3! + ...
#
# We can start by defining a new function g(x) = f(x) - (e^a + e^a (x - a) + e^a (x - a)^2 / 2! + e^a (x - a)^3 / 3! + ...).
#
# This function is infinitely differentiable at a.
#
# Using the definition of the derivative, we can find the derivative of g(x):
#
# g'(x) = f'(x) - (e^a + e^a (x - a) + e^a (x - a)^2 / 2! + e^a (x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g'(a) = 0
#
# Using the definition of the derivative again, we can find the second derivative of g(x):
#
# g''(x) = f''(x) - (e^a + e^a (x - a) + e^a (x - a)^2 / 2! + e^a (x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g''(a) = 0
#
# Continuing this process, we can find the nth derivative of g(x):
#
# g^(n)(x) = f^(n)(x) - (e^a + e^a (x - a) + e^a (x - a)^2 / 2! + e^a (x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g^(n)(a) = 0
#
# Since g(x) is infinitely differentiable at a, we know that g^(n)(a) = 0 for all n.
#
# Using the definition of the Taylor Series, we can write:
#
# g(x) = g(a) + g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ...
#
# Since g(a) = 0, we can simplify this to:
#
# g(x) = g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ...
#
# Continuing this process, we can write:
#
# g(x) = g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ... + g^(n)(a)(x - a)^n / n! + ...
#
# Since g^(n)(a) = 0 for all n, we can simplify this to:
#
# g(x) = 0
#
# This shows that the Taylor Series of f(x) = e^x is given by:
#
# f(x) = e^a + e^a (x - a) + e^a (x - a)^2 / 2! + e^a (x - a)^3 / 3! + ...
#
# 4. The Taylor Series of the function f(x) = sin(x) is given by:
#
# f(x) = sin(a) + cos(a) (x - a) - sin(a) (x - a)^2 / 2! + cos(a) (x - a)^3 / 3! + ...
#
# This can be proved using the definition of the Taylor Series as follows:
#
# Let f(x) = sin(x). We want to show that the Taylor Series of f(x) is given by:
#
# f(x) = sin(a) + cos(a) (x - a) - sin(a) (x - a)^2 / 2! + cos(a) (x - a)^3 / 3! + ...
#
# We can start by defining a new function g(x) = f(x) - (sin(a) + cos(a) (x - a) - sin(a) (x - a)^2 / 2! + cos(a) (x - a)^3 / 3! + ...).
#
# This function is infinitely differentiable at a.
#
# Using the definition of the derivative, we can find the derivative of g(x):
#
# g'(x) = f'(x) - (cos(a) - sin(a) (x - a) - cos(a) (x - a)^2 / 2! + sin(a) (x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g'(a) = 0
#
# Using the definition of the derivative again, we can find the second derivative of g(x):
#
# g''(x) = f''(x) - (-sin(a) - cos(a) (x - a) - sin(a) (x - a)^2 / 2! + cos(a) (x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g''(a) = 0
#
# Continuing this process, we can find the nth derivative of g(x):
#
# g^(n)(x) = f^(n)(x) - (cos(a) - sin(a) (x - a) - cos(a) (x - a)^2 / 2! + sin(a) (x - a)^3 / 3! + ...)
#
# Evaluating this at x = a, we get:
#
# g^(n)(a) = 0
#
# Since g(x) is infinitely differentiable at a, we know that g^(n)(a) = 0 for all n.
#
# Using the definition of the Taylor Series, we can write:
#
# g(x) = g(a) + g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ...
#
# Since g(a) = 0, we can simplify this to:
#
# g(x) = g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ...
#
# Continuing this process, we can write:
#
# g(x) = g'(a)(x - a) + g''(a)(x - a)^2 / 2! + g'''(a)(x - a)^3 / 3! + ... + g^(n)(a)(x - a)^n / n! + ...
#
# Since g^(n)(a) = 0 for all n, we can simplify this to:
#
# g(x) = 0
#
# This shows that the Taylor Series of f(x) = sin(x) is given by:
#
# f(x) = sin(a) + cos(a) (x - a) - sin(a) (x - a)^2 / 2! + cos(a) (x - a)^3 / 3! + ...
#
# 5. The Taylor Series of the function f(x) = e^x can be used to approximate the value of the function at x = 2 as follows:
#
# f(2) = e^2 = e^a + e^a (2 - a) + e^a (2 - a)^2 / 2! + e^a (2 - a)^3 / 3! + ...
#
# We can approximate this value by truncating the Taylor Series at a certain point. For example, we can approximate f(2) by truncating the Taylor Series at the term e^a (2 - a)^2 / 2!.
#
# This gives us:
#
# f(2) ≈ e^a + e^a (2 - a) + e^a (2 - a)^2 / 2!
#
# We can evaluate this expression at a = 0 to get:
#
# f(2) ≈ e^0 + e^0 (2 - 0) + e^0 (2 - 0)^2 / 2!
#
# This simplifies to:
#
# f(2) ≈ 1 + 2 + 1 = 4
#
# This is a good approximation of the value of f(2) = e^2.
#
# Note: This is a very basic approximation and the actual value of e^2 is approximately 7.38905609893065.
#
#
# ----------------------------------------------------------------------------------------------------
# Lesson 50: Conclusion and Future Directions in Calculus
#
# <p>Error generating content: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jn09qcw3e1avgw2q9vxda0gz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5901, Requested 272. Please try again in 1.73s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}</p>
#
#
# ----------------------------------------------------------------------------------------------------
